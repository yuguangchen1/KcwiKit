# %%
import os
import numpy as np
import glob
import kcwi
import pdb
import importlib

# %reload_ext autoreload
# %autoreload
# %matplotlib inline

#from astropy.utils import iers
#iers.Conf.iers_auto_url.set('ftp://cddis.gsfc.nasa.gov/pub/products/iers/finals2000A.all')
#importlib.reload(kcwi)

from IPython.display import Audio
sound_file = '/scr/yuguangchen/beep-01a.wav'

# %%
fn='q0256-md34.list'

# %%
kcwi.kcwi_align(fn,noalign=True)
# Out:
# kb200125_00064_icubes.fits
# kb200125_00065_icubes.fits
# kb200125_00066_icubes.fits
# kb200126_00080_icubes.fits
# kb200126_00081_icubes.fits
# kb200126_00082_icubes.fits
# kb210115_00043_icubes.fits
# kb210115_00044_icubes.fits
# kb210115_00045_icubes.fits
# kb210115_00046_icubes.fits
# kb210115_00047_icubes.fits
# kb210115_00048_icubes.fits
# kb210115_00052_icubes.fits
# kb210906_00068_icubes.fits
# kb210906_00069_icubes.fits
# kb210906_00070_icubes.fits
# kb210906_00071_icubes.fits
# kb210906_00072_icubes.fits
# kb210906_00073_icubes.fits

# %%
kcwi.kcwi_align(fn)
# Out:
# kb200125_00064_icubes.fits
# kb200125_00065_icubes.fits
# 0.31245327854134786 0.14556707821683545
# kb200125_00066_icubes.fits
# 0.7955842532089292 0.40953909244633024
# kb200126_00080_icubes.fits
# 0.044187565546085494 2.4703557314467943
# kb200126_00081_icubes.fits
# 1.1873224657700163 1.3101038547602926
# kb200126_00082_icubes.fits
# 1.7459000256439232 0.5335762293095172
# kb210115_00043_icubes.fits
# -2.6066496367607535 -1.8559457608186207
# kb210115_00044_icubes.fits
# 0.21891343031216337 -0.6546963742721346
# kb210115_00045_icubes.fits
# -1.4140024631431807 -1.44103919732202
# kb210115_00046_icubes.fits
# -0.2812079552132438 0.07278376761925642
# kb210115_00047_icubes.fits
# 0.8395638047902985 0.10293150726241862
# kb210115_00048_icubes.fits
# 1.041580413974934 5.849344321940762
# kb210115_00052_icubes.fits
# -2.383302488785805 0.4706041594043242
# kb210906_00068_icubes.fits
# 1.6349399943374827 0.8234519806019875
# kb210906_00069_icubes.fits
# ...

# %%
kcwi.kcwi_check_flux(fn)

# %%
kcwi.kcwi_norm_flux(fn, frame=[6,7,8,9,10,11,12])
# Out:
# <Table length=19>
#                                 col0                                ...
#                                str67                                ...
# ------------------------------------------------------------------- ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan20/2020jan25/redux/kb200125_00064 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan20/2020jan25/redux/kb200125_00065 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan20/2020jan25/redux/kb200125_00066 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan20/2020jan26/redux/kb200126_00080 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan20/2020jan26/redux/kb200126_00081 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan20/2020jan26/redux/kb200126_00082 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan21/2021jan15/redux/kb210115_00043 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan21/2021jan15/redux/kb210115_00044 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan21/2021jan15/redux/kb210115_00045 ...
# /scr/yuguangchen/obs/kcwi/kcwi_jan21/2021jan15/redux/kb210115_00046 ...
# ...

# %%
kcwi.kcwi_stack(fn,overwrite=True)
# Out:
# Projecting...
# kb200125_00064_icubes.fits
#      Vcorr = -26.271006992522437
#      EXPTIME = 1200.0
# kb200125_00065_icubes.fits
#      Vcorr = -26.274782868468318
#      EXPTIME = 1200.0
# kb200125_00066_icubes.fits
#      Vcorr = -26.27491951870042
#      EXPTIME = 1200.0
# kb200126_00080_icubes.fits
#      Vcorr = -25.987564234526236
#      EXPTIME = 1200.0
#   Different wavelength grid: interpolating...
# kb200126_00081_icubes.fits
#      Vcorr = -25.99173156297051
#      EXPTIME = 1200.0
#   Different wavelength grid: interpolating...
# kb200126_00082_icubes.fits
#      Vcorr = -25.992270368911765
#      EXPTIME = 1200.0
#   Different wavelength grid: interpolating...
# kb210115_00043_icubes.fits
#      Vcorr = -28.353353864159548
#      EXPTIME = 1200.0
#   Different wavelength grid: interpolating...
# kb210115_00044_icubes.fits
#      Vcorr = -28.380491237160182
#      EXPTIME = 1200.0
#   Different wavelength grid: interpolating...
# kb210115_00045_icubes.fits
# ...

# %%
kcwi.kcwi_astrometry(fn)
Audio(sound_file, autoplay=True)
# Out:
# q0256-md34.list
# Iter: 1/2
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid DATE-OBS format '14Oct96           ''. [astropy.wcs.wcs]
# Iter: 2/2
# 0.5 2.0
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
